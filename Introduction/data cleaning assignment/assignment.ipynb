# %%
import pandas as pd

# %% [markdown]
# ### Assignment in Pandas
# #### 1. Reading in Files
#   - Read .csv files using pandas (countries of the world.csv)
#   - Read .txt files using ```read_csv``` and ```read_table``` (countries of the world.txt)
#   - Read json files json_sample.json
#   - Read excel file (world_population_excel_workbook.xlsx) sheet 1

# %%
df = pd.read_csv('countriesoftheworld.csv')
df
# Out:
#              Country                               Region
# 0       Afghanistan         ASIA (EX. NEAR EAST)
# 1           Albania   EASTERN EUROPE
# 2           Algeria   NORTHERN AFRICA
# 3    American Samoa   OCEANIA
# 4           Andorra   WESTERN EUROPE
# ..               ...                                  ...
# 222       West Bank   NEAR EAST
# 223  Western Sahara   NORTHERN AFRICA
# 224           Yemen   NEAR EAST
# 225          Zambia   SUB-SAHARAN AFRICA
# 226        Zimbabwe   SUB-SAHARAN AFRICA
#
# [227 rows x 2 columns]

# %%
df1 = pd.read_table('countriesoftheworld.csv')
df1
# Out:
#                                         Country,Region
# 0           Afghanistan ,ASIA (EX. NEAR EAST)
# 1         Albania ,EASTERN EUROPE
# 2         Algeria ,NORTHERN AFRICA
# 3    American Samoa ,OCEANIA                       ...
# 4         Andorra ,WESTERN EUROPE
# ..                                                 ...
# 222     West Bank ,NEAR EAST
# 223  Western Sahara ,NORTHERN AFRICA               ...
# 224         Yemen ,NEAR EAST
# 225        Zambia ,SUB-SAHARAN AFRICA
# 226      Zimbabwe ,SUB-SAHARAN AFRICA
#
# [227 rows x 1 columns]

# %%
pd.read_table('countriesoftheworld.txt')
# Out:
#              Country                               Region
# 0       Afghanistan         ASIA (EX. NEAR EAST)
# 1           Albania   EASTERN EUROPE
# 2           Algeria   NORTHERN AFRICA
# 3    American Samoa   OCEANIA
# 4           Andorra   WESTERN EUROPE
# ..               ...                                  ...
# 222       West Bank   NEAR EAST
# 223  Western Sahara   NORTHERN AFRICA
# 224           Yemen   NEAR EAST
# 225          Zambia   SUB-SAHARAN AFRICA
# 226        Zimbabwe   SUB-SAHARAN AFRICA
#
# [227 rows x 2 columns]

# %%
df2 = pd.read_json('json_sample.json')
df2
# Out:
#                                            12 Strong  \
# 0  {'Genre': 'Action', 'Gross': '$453,173', 'IMDB...
#
#             A Fantastic Woman (Una Mujer Fantástica)  \
# 0  {'popcornscore': 83, 'rating': 'R', 'tomatosco...
#
#                           All The Money In The World  \
# 0  {'popcornscore': 71, 'rating': 'R', 'tomatosco...
#
#                           Bilal: A New Breed Of Hero  \
# 0  {'popcornscore': 91, 'rating': 'PG13', 'tomato...
#
#                                 Call Me By Your Name  \
# 0  {'popcornscore': 87, 'rating': 'R', 'tomatosco...
#
#                                         Darkest Hour  \
# 0  {'popcornscore': 84, 'rating': 'PG13', 'tomato...
#
#                                       Den Of Thieves  \
# 0  {'Genre': 'Action', 'Gross': '$491,898', 'IMDB...
#
#                                            Ferdinand  \
# 0  {'popcornscore': 49, 'rating': 'PG', 'tomatosc...
#
#                                   Fifty Shades Freed  \
# ...

# %%
df3 = pd.read_excel('world_population_excel_workbook.xlsx', sheet_name='Sheet1')
df3
# Out:
#      Rank CCA3            Country           Capital
# 0      36  AFG        Afghanistan             Kabul
# 1     138  ALB            Albania            Tirana
# 2      34  DZA            Algeria           Algiers
# 3     213  ASM     American Samoa         Pago Pago
# 4     203  AND            Andorra  Andorra la Vella
# ..    ...  ...                ...               ...
# 229   226  WLF  Wallis and Futuna          Mata-Utu
# 230   172  ESH     Western Sahara         El AaiÃºn
# 231    46  YEM              Yemen             Sanaa
# 232    63  ZMB             Zambia            Lusaka
# 233    74  ZWE           Zimbabwe            Harare
#
# [234 rows x 4 columns]

# %% [markdown]
# #### 2. Filtering and Ordering in Pandas
#   - Read csv file world_population.csv
#   - Display the list of countries having a rank<= 10
#   - Create a list of specific country ```['Bangladesh', 'Brazil']``` and return
#   df which falls under the specific list only
#   - Apply filter to the Country which has ```United``` in its name
#   - Create a dataframe df2 and give Country as its index
#   - Apply filter Continent and CCA3 in df2 (need only two columns)
#   - Apply filter to see details of ```Zimbabwe``` entire row

# %%
df = pd.read_csv('world_population.csv')
df1=df.sort_values(by=['Continent', 'Country'], ascending=[False, True])
df1
# Out:
#      Rank CCA3         Country       Capital      Continent  2022 Population  \
# 8      33  ARG       Argentina  Buenos Aires  South America       45510318.0
# 24     80  BOL         Bolivia         Sucre  South America       12224110.0
# 27      7  BRA          Brazil      Brasilia  South America      215313498.0
# 40     65  CHL           Chile      Santiago  South America       19603733.0
# 42     28  COL        Colombia        Bogota  South America       51874024.0
# ..    ...  ...             ...           ...            ...              ...
# 212    79  TUN         Tunisia         Tunis         Africa       12356117.0
# 217    31  UGA          Uganda       Kampala         Africa       47249585.0
# 230   172  ESH  Western Sahara      El Aaiún         Africa         575986.0
# 232    63  ZMB          Zambia        Lusaka         Africa       20017675.0
# 233    74  ZWE        Zimbabwe        Harare         Africa       16320537.0
#
# ...

# %%
df[df['Rank']<=10]
# Out:
#      Rank CCA3        Country           Capital      Continent  \
# 16      8  BGD     Bangladesh             Dhaka           Asia
# 27      7  BRA         Brazil          Brasilia  South America
# 41      1  CHN          China           Beijing           Asia
# 92      2  IND          India         New Delhi           Asia
# 93      4  IDN      Indonesia           Jakarta           Asia
# 131    10  MEX         Mexico       Mexico City  North America
# 149     6  NGA        Nigeria             Abuja         Africa
# 156     5  PAK       Pakistan         Islamabad           Asia
# 171     9  RUS         Russia            Moscow         Europe
# 221     3  USA  United States  Washington, D.C.  North America
#
#      2022 Population  2020 Population  2015 Population  2010 Population  \
# 16      1.711864e+08     1.674210e+08     1.578300e+08     1.483911e+08
# 27      2.153135e+08     2.131963e+08     2.051882e+08     1.963535e+08
# ...

# %%
df[df['Country'].isin(['Bangladesh', 'Brazil'])]
# Out:
#     Rank CCA3     Country   Capital      Continent  2022 Population  \
# 16     8  BGD  Bangladesh     Dhaka           Asia      171186372.0
# 27     7  BRA      Brazil  Brasilia  South America      215313498.0
#
#     2020 Population  2015 Population  2010 Population  2000 Population  \
# 16      167420951.0      157830000.0      148391139.0      129193327.0
# 27      213196304.0      205188205.0      196353492.0      175873720.0
#
#     1990 Population  1980 Population  1970 Population  Area (km²)  \
# 16      107147651.0       83929765.0       67541860.0    147570.0
# 27      150706446.0      122288383.0       96369875.0   8515767.0
#
#     Density (per km²)  Growth Rate  World Population Percentage
# 16          1160.0350       1.0108                         2.15
# 27            25.2841       1.0046                         2.70

# %%
df[df['Country'].str.contains('United')]
# Out:
#      Rank CCA3                       Country           Capital      Continent  \
# 219    97  ARE          United Arab Emirates         Abu Dhabi           Asia
# 220    21  GBR                United Kingdom            London         Europe
# 221     3  USA                 United States  Washington, D.C.  North America
# 222   200  VIR  United States Virgin Islands  Charlotte Amalie  North America
#
#      2022 Population  2020 Population  2015 Population  2010 Population  \
# 219        9441129.0        9287289.0        8916899.0        8481771.0
# 220       67508936.0       67059474.0       65224364.0       62760039.0
# 221      338289857.0      335942003.0      324607776.0      311182845.0
# 222          99465.0         100442.0         102803.0         106142.0
#
#      2000 Population  1990 Population  1980 Population  1970 Population  \
# 219        3275333.0        1900151.0        1014048.0         298084.0
# ...

# %%
df2 = df
df2.index = df2['Country']
df2
# Out:
#                    Rank CCA3            Country           Capital Continent  \
# Country
# Afghanistan          36  AFG        Afghanistan             Kabul      Asia
# Albania             138  ALB            Albania            Tirana    Europe
# Algeria              34  DZA            Algeria           Algiers    Africa
# American Samoa      213  ASM     American Samoa         Pago Pago   Oceania
# Andorra             203  AND            Andorra  Andorra la Vella    Europe
# ...                 ...  ...                ...               ...       ...
# Wallis and Futuna   226  WLF  Wallis and Futuna          Mata-Utu   Oceania
# Western Sahara      172  ESH     Western Sahara          El Aaiún    Africa
# Yemen                46  YEM              Yemen             Sanaa      Asia
# Zambia               63  ZMB             Zambia            Lusaka    Africa
# Zimbabwe             74  ZWE           Zimbabwe            Harare    Africa
#
# ...

# %%
df2[['Continent', 'CCA3']]
# Out:
#                   Continent CCA3
# Country
# Afghanistan            Asia  AFG
# Albania              Europe  ALB
# Algeria              Africa  DZA
# American Samoa      Oceania  ASM
# Andorra              Europe  AND
# ...                     ...  ...
# Wallis and Futuna   Oceania  WLF
# Western Sahara       Africa  ESH
# Yemen                  Asia  YEM
# Zambia               Africa  ZMB
# Zimbabwe             Africa  ZWE
#
# [234 rows x 2 columns]

# %%
df2[df2['Country']=='Zimbabwe']
# Out:
#           Rank CCA3   Country Capital Continent  2022 Population  \
# Country
# Zimbabwe    74  ZWE  Zimbabwe  Harare    Africa       16320537.0
#
#           2020 Population  2015 Population  2010 Population  2000 Population  \
# Country
# Zimbabwe       15669666.0       14154937.0       12839771.0       11834676.0
#
#           1990 Population  1980 Population  1970 Population  Area (km²)  \
# Country
# Zimbabwe       10113893.0        7049926.0        5202918.0    390757.0
#
#           Density (per km²)  Growth Rate  World Population Percentage
# Country
# Zimbabwe            41.7665       1.0204                          0.2

# %%
df2=pd.MultiIndex.from_frame(df2, names=['Continent','Country'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[103], line 1
# ----> 1 df2=pd.MultiIndex.from_frame(df2, names=['Continent','Country'])
#
# File ~/anaconda3/lib/python3.12/site-packages/pandas/core/indexes/multi.py:754, in MultiIndex.from_frame(cls, df, sortorder, names)
#     752 column_names, columns = zip(*df.items())
#     753 names = column_names if names is None else names
# --> 754 return cls.from_arrays(columns, sortorder=sortorder, names=names)
#
# File ~/anaconda3/lib/python3.12/site-packages/pandas/core/indexes/multi.py:537, in MultiIndex.from_arrays(cls, arrays, sortorder, names)
#     534 if names is lib.no_default:
#     535     names = [getattr(arr, "name", None) for arr in arrays]
# --> 537 return cls(
#     538     levels=levels,
#     539     codes=codes,
#     540     sortorder=sortorder,
#     541     names=names,
# ...
