# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import make_blobs

# %% [markdown]
# Step 2: Create the custom dataset with make_bolbs and plot it

# %%
x, y = make_blobs (n_samples=500, n_features=2, centers=3, random_state=23)
fig= plt.figure(0)
plt.grid(True)
plt.scatter(x[:,0],x[:,1])
plt.show()

# %% [markdown]
# Step 3: Initialize the random centroids
# The code initializes three clusters for k-means clustering. It sets  a random seed and generates random cluster centers within a specified range, and creates an empty list of points of each cluster

# %%
k = 3
clusters = {}
np.random.seed(23)
for idx in range(k):
  center = 2*(2*np.random.random((x.shape[1],))-1)
  points = []
  cluster = {
      'center':center,
      'points':[]
  }
  clusters[idx] = cluster
clusters
# Out:
# {0: {'center': array([0.06919154, 1.78785042]), 'points': []},
#  1: {'center': array([ 1.06183904, -0.87041662]), 'points': []},
#  2: {'center': array([-1.11581855,  0.74488834]), 'points': []}}

# %% [markdown]
# Step 4:

# %%
plt.scatter(x[:,0],x[:,1])
plt.grid(True)
for i in clusters:
  center = clusters[i]['center']
  plt.scatter(center[0],center[1],marker='*',c = 'purple')
plt.show()

# %% [markdown]
# Step 5

# %%
def distance(p1,p2):
  return np.sqrt(np.sum((p1-p2)**2))

# %% [markdown]
# Step 6

# %%
def assign_clusters(x,clusters):
  for idx in range(x.shape[0]):
    dist = []
    curr_x = x[idx]
    for i in range(k):
      dis = distance(curr_x,clusters[i]['center'])
      dist.append(dis)
    curr_cluster = np.argmin(dist)
    clusters[curr_cluster]['points'].append(curr_x)
  return clusters

def update_clusters(x,clusters):
  for i in range(k):
    points= np.array(clusters[i]['points'])
    if points.shape[0]>0:
      new_center = points.mean(axis = 0)
      clusters[i]['center'] = new_center
      clusters[i]['points'] = []
  return clusters

# %% [markdown]
# Step 7: Create the function to predict the cluster for the datapoints

# %%
def pred_cluster(x,clusters):
  pred = []
  for i in range(x.shape[0]):
    dist = []
    for j in range(k):
      dist.append(distance(x[i],clusters[j]['center']))
    pred.append(np.argmin(dist))
  return pred

# %% [markdown]
# Step 8: Assign,Update and predict the cluster center

# %%
clusters = assign_clusters(x,clusters)
clusters = update_clusters(x,clusters)
pred = pred_cluster(x,clusters)

# %% [markdown]
# Step 9

# %%
plt.scatter(x[:,0],x[:,1],c = pred)
for i in clusters:
  center = clusters[i]['center']
  plt.scatter(center[0],center[1],marker = '^',c = 'red')
plt.show()
